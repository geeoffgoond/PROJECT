# %% [markdown]
# # Geoffrey Gund - Governance Analytics Project

# %% [markdown]
# # Step 1: get the data

# %%
#%% specifying data location data from gitHub, preparing data
import os
import xlrd
folderData="https://rawgit.com/geeoffgoond/project/master/"
fileXL=os.path.join(folderData,"2015-pr1-hhsurvey-household.xlsx")

# importing data into pandas
import pandas as pd

psrchh=pd.read_excel(fileXL)

# %% [markdown]
# # Step 2: lets look at the data and limit it to what we need

# %%
#checking what columns we have
psrchh.columns
# Out:
# Index(['hhid', 'sampletype', 'tacoma_addon', 'traveldate', 'dayofweek',
#        'hhnumtrips', 'vehicle_count', 'hhsize', 'numadults', 'numchildren',
#        'numworkers', 'lifecycle', 'hh_income_detailed', 'hh_income_followup',
#        'hh_income_broad', 'sample_segname', 'h_cnty', 'h_city', 'h_zip',
#        'address_use_flag', 'panel_moveinspect', 'h_segname', 'h_county_name',
#        'h_district_name', 'h_rgc_name', 'h_school_district_name', 'h_uv_name',
#        'h_uv_group', 'h_tract', 'h_bg', 'h_puma10', 'res_months', 'res_dur',
#        'rent_own', 'res_type', 'res_factors_hhchange', 'res_factors_afford',
#        'res_factors_school', 'res_factors_walk', 'res_factors_space',
#        'res_factors_closefam', 'res_factors_transit', 'res_factors_hwy',
#        'res_factors_30min', 'prev_rent_own', 'prev_res_type', 'prev_home_wa',
#        'prev_home_loc_cnty', 'prev_home_loc_city', 'prev_home_loc_zip',
#        'prev_home_loc_st', 'prev_home_loc_x', 'hh_info_dur', 'incentive_type',
#        'incentive_amt', 'user_ismobiledevice', 'foreign_language',
#        'expwt_h1415'],
#       dtype='object')

# %%
#we're only interested in a few of those, so let's limit it to those
psrchh=psrchh[["hhid", "hhnumtrips", "hh_income_detailed", "h_zip", "h_city", "res_factors_hhchange", "res_factors_afford", "res_factors_school", "res_factors_walk", "res_factors_space", "res_factors_closefam", "res_factors_transit", "res_factors_hwy", "res_factors_30min", "prev_home_loc_zip", "prev_home_loc_city", "prev_home_loc_st"]]

#checking to make sure it worked:
psrchh.columns
# Out:
# Index(['hhid', 'hhnumtrips', 'hh_income_detailed', 'h_zip', 'h_city',
#        'res_factors_hhchange', 'res_factors_afford', 'res_factors_school',
#        'res_factors_walk', 'res_factors_space', 'res_factors_closefam',
#        'res_factors_transit', 'res_factors_hwy', 'res_factors_30min',
#        'prev_home_loc_zip', 'prev_home_loc_city', 'prev_home_loc_st'],
#       dtype='object')

# %%
#this contains information for all of Washington
#we're only interested in the Puget Sound Region 
#so let's limit it to the counties here:
fileZips=os.path.join(folderData,"waStateZips.xlsx") #getting an excel file with WA state zips by county
waStateZips=pd.read_excel(fileZips) 

#dropping missing zips:
####waStateZips.zip.dropna()

#checking the data quickly
####waStateZips.zip.dtype

# %%
#let's make our zips integers for later:
#waStateZips.zip=waStateZips.zip.astype(int)

# %%
#setting the file to the counties we're interested in:
PugetSoundCounties = ["KING", "KITSAP", "PIERCE", "SNOHOMISH", "ISLANDS"] #can change
psZips = waStateZips[(waStateZips['County Name']).isin(PugetSoundCounties)] #creates a dataFrame of data from those counties
#psZips #see the dataFrame to verify (if we'd like)

psZips.reset_index(inplace=True,drop=True) # resetting the index
psrchh = psrchh[(psrchh["h_zip"]).isin(psZips.zip)] #restricting our dataset to just those zipcodes in the counties we specified

#dropping na
psrchh.dropna(axis=0,inplace=True)

psrchh.head() #checking to make sure it still looks good! it does

# %% [markdown]
# # Step 3: let's explore the data

# %%
#we're looking into why people moved where they moved, so let's check that out:
#all factors were rated 1-5. Let's first look at Change of Household:

psrchh['res_factors_hhchange'].describe()
# Out:
# count    810.000000
# mean       2.803704
# std        1.328488
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: res_factors_hhchange, dtype: float64

# %%
#now let's look at affordability:
psrchh['res_factors_afford'].describe()
# Out:
# count    810.000000
# mean       4.307407
# std        1.072441
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# Name: res_factors_afford, dtype: float64

# %%
#let's look at schools:
psrchh['res_factors_school'].describe()
# Out:
# count    810.000000
# mean       2.601235
# std        1.447131
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: res_factors_school, dtype: float64

# %%
#walkability:
psrchh['res_factors_walk'].describe()
# Out:
# count    810.000000
# mean       4.174074
# std        1.098631
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# Name: res_factors_walk, dtype: float64

# %%
#desire for more space:
psrchh['res_factors_space'].describe()
# Out:
# count    810.000000
# mean       3.456790
# std        1.266175
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000
# Name: res_factors_space, dtype: float64

# %%
#to be closer to family:
psrchh['res_factors_closefam'].describe()
# Out:
# count    810.000000
# mean       3.417284
# std        1.260289
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000
# Name: res_factors_closefam, dtype: float64

# %%
#better transit access:
psrchh['res_factors_transit'].describe()
# Out:
# count    810.000000
# mean       3.686420
# std        1.379862
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: res_factors_transit, dtype: float64

# %%
#to be closer to the highway
psrchh['res_factors_hwy'].describe()
# Out:
# count    810.000000
# mean       3.106173
# std        1.280678
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: res_factors_hwy, dtype: float64

# %%
#to have a commute under 30 minutes
psrchh['res_factors_30min'].describe()
# Out:
# count    810.000000
# mean       3.835802
# std        1.351263
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: res_factors_30min, dtype: float64

# %% [markdown]
# # Step 4: Let's see if we can cluster these reasons for moving

# %%
#%% clustering
len(psrchh.hhid.unique())==len(psrchh.hhid) #checking to make sure hhid (the clustering units) are unique
# Out:
# True

# %%
psrchh.index=psrchh.hhid #setting hhid as the index
psrchh.iloc[:,5:14].dtypes #checking dtypes of clustering columns
# Out:
# res_factors_hhchange    int64
# res_factors_afford      int64
# res_factors_school      int64
# res_factors_walk        int64
# res_factors_space       int64
# res_factors_closefam    int64
# res_factors_transit     int64
# res_factors_hwy         int64
# res_factors_30min       int64
# dtype: object

# %%
# standardize data:
from sklearn import preprocessing

ps_scaled = preprocessing.scale(psrchh.loc[:,'res_factors_hhchange': 'res_factors_30min'])

#compute similarity matrix
from scipy.spatial.distance import pdist, squareform

psSimi_simple = pdist(ps_scaled,metric='euclidean') # output is not matrix
psSimi_matrix =squareform(psSimi_simple) # this is a matrix

# %%
from scipy.cluster.hierarchy import linkage, cut_tree
# computing the linkage
psSimi_link = linkage(psSimi_simple,method='average')

# %%
# %matplotlib inline
import seaborn as sns

g = sns.clustermap(psrchh.loc[:,'res_factors_hhchange': 'res_factors_30min'],
                   metric='euclidean',
                   method='average',
                   col_cluster=False,
                  figsize=(10, 20))

# %%
#doesn't look like there's a great way to cluster, but we'll also check numericallY:
from sklearn.metrics import silhouette_score
from numpy import ravel

for nOfClusters in range(2,5):
    # get cluster labels
    clusterLabels = ravel(cut_tree(psSimi_link, nOfClusters)) # formatting cut_tree output with ravel
    # get silhouettes
    silhouette_avg = silhouette_score(psSimi_matrix,clusterLabels,metric='precomputed')
    
    # print results:
    print("For n_clusters =", nOfClusters, 
          "The average silhouette_score is:", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is: 0.346145181428
# For n_clusters = 3 The average silhouette_score is: 0.247691959239
# For n_clusters = 4 The average silhouette_score is: 0.213699290246

# %%
#all of those silhouette scores are quite low, so we'll do something else

# %% [markdown]
# # Step 5: Let's try a different method of simplification: we'll create a dataframe that collapses the data into means by zipcode

# %%
#let's create a variable with all the different move factors:
resfacNames=psrchh.columns[psrchh.columns.str.contains('res_factors')].tolist()
resfacNames
# Out:
# ['res_factors_hhchange',
#  'res_factors_afford',
#  'res_factors_school',
#  'res_factors_walk',
#  'res_factors_space',
#  'res_factors_closefam',
#  'res_factors_transit',
#  'res_factors_hwy',
#  'res_factors_30min']

# %%
psrchh[resfacNames].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 810 entries, 14100007 to 15100819
# Data columns (total 9 columns):
# res_factors_hhchange    810 non-null int64
# res_factors_afford      810 non-null int64
# res_factors_school      810 non-null int64
# res_factors_walk        810 non-null int64
# res_factors_space       810 non-null int64
# res_factors_closefam    810 non-null int64
# res_factors_transit     810 non-null int64
# res_factors_hwy         810 non-null int64
# res_factors_30min       810 non-null int64
# dtypes: int64(9)
# memory usage: 63.3 KB

# %%
psrchh[resfacNames].describe() #great
# Out:
#        res_factors_hhchange  res_factors_afford  res_factors_school  \
# count            810.000000          810.000000          810.000000
# mean               2.803704            4.307407            2.601235
# std                1.328488            1.072441            1.447131
# min                1.000000            1.000000            1.000000
# 25%                1.000000            4.000000            1.000000
# 50%                3.000000            5.000000            3.000000
# 75%                4.000000            5.000000            4.000000
# max                5.000000            5.000000            5.000000
#
#        res_factors_walk  res_factors_space  res_factors_closefam  \
# count        810.000000         810.000000            810.000000
# mean           4.174074           3.456790              3.417284
# std            1.098631           1.266175              1.260289
# min            1.000000           1.000000              1.000000
# 25%            4.000000           3.000000              3.000000
# 50%            5.000000           4.000000              4.000000
# 75%            5.000000           4.000000              4.000000
# max            5.000000           5.000000              5.000000
#
#        res_factors_transit  res_factors_hwy  res_factors_30min
# count           810.000000       810.000000         810.000000
# mean              3.686420         3.106173           3.835802
# std               1.379862         1.280678           1.351263
# min               1.000000         1.000000           1.000000
# 25%               3.000000         2.000000           3.000000
# 50%               4.000000         3.000000           4.000000
# 75%               5.000000         4.000000           5.000000
# max               5.000000         5.000000           5.000000

# %%
#We'll use groupby to create a new dataframe that groups our data by the zipcode of the resident:
#we'll also use this data for a map
psMove = psrchh.groupby(['h_zip'], as_index=False)[resfacNames].mean() #might be onto something here
psMove #looks great
# Out:
#      h_zip  res_factors_hhchange  res_factors_afford  res_factors_school  \
# 0    98001              4.000000            5.000000            3.000000
# 1    98002              3.200000            4.000000            2.800000
# 2    98003              2.333333            4.333333            2.333333
# 3    98004              2.666667            3.500000            2.833333
# 4    98005              5.000000            4.000000            5.000000
# 5    98006              3.666667            4.333333            4.833333
# 6    98007              2.818182            4.090909            3.363636
# 7    98008              2.000000            3.000000            2.000000
# 8    98011              2.000000            3.500000            1.500000
# 9    98012              3.571429            4.571429            3.285714
# 10   98019              5.000000            4.000000            5.000000
# 11   98020              3.333333            4.555556            3.111111
# 12   98021              3.000000            4.000000            3.200000
# 13   98022              3.000000            4.000000            3.000000
# 14   98023              2.000000            3.000000            2.500000
# 15   98024              3.000000            2.000000            1.000000
# 16   98026              3.000000            4.800000            1.800000
# 17   98027              2.750000            3.500000            3.750000
# 18   98028              2.750000            4.000000            3.875000
# 19   98029              2.714286            3.714286            3.642857
# 20   98030              2.833333            5.000000            2.333333
# 21   98031              3.000000            5.000000            3.000000
# 22   98032              3.000000            3.000000            2.500000
# 23   98033              3.555556            4.222222            3.555556
# 24   98034              2.875000            4.250000            3.125000
# 25   98036              4.500000            5.000000            4.000000
# 26   98037              1.000000            5.000000            1.000000
# 27   98038              3.000000            5.000000            5.000000
# 28   98040              4.000000            4.000000            2.500000
# 29   98042              2.000000            4.000000            2.500000
# ..     ...                   ...                 ...                 ...
# 108  98372              5.000000            5.000000            2.000000
# 109  98373              2.750000            4.750000            2.500000
# 110  98374              3.333333            4.666667            4.666667
# 111  98375              2.000000            3.000000            3.500000
# 112  98383              3.000000            4.000000            3.000000
# 113  98388              3.000000            5.000000            5.000000
# 125          3.800000           3.400000              3.200000
# 126          4.000000           3.666667              2.666667
# 127          5.000000           2.000000              3.000000
# 128          5.000000           1.000000              3.000000
# 129          3.666667           4.000000              4.666667
# 130          5.000000           5.000000              5.000000
# 131          4.000000           4.000000              4.000000
# 132          4.500000           3.666667              4.166667
# 133          3.000000           4.500000              4.000000
# 134          5.000000           4.000000              5.000000
# 135          4.000000           3.000000              3.500000
# 136          3.000000           3.000000              3.714286
# 137          3.500000           4.500000              2.500000
#
#      res_factors_transit  res_factors_hwy  res_factors_30min
# 0               4.000000         5.000000           5.000000
# 1               3.200000         2.600000           3.000000
# 2               2.666667         3.333333           2.666667
# 3               3.166667         4.000000           3.500000
# 4               3.000000         3.000000           5.000000
# 5               2.833333         4.333333           3.833333
# 6               4.000000         2.545455           3.727273
# 7               3.000000         3.000000           3.000000
# 8               2.000000         2.000000           3.000000
# 9               2.428571         4.285714           4.142857
# 10              4.000000         1.000000           4.000000
# 11              2.777778         3.555556           3.777778
# 12              2.200000         3.000000           3.400000
# 13              2.000000         5.000000           5.000000
# 14              3.500000         3.500000           4.000000
# 15              5.000000         4.000000           3.000000
# 16              3.400000         3.800000           2.600000
# 17              3.500000         4.500000           5.000000
# 18              3.500000         2.625000           3.125000
# 19              3.071429         3.357143           3.785714
# 20              3.666667         3.333333           4.000000
# 21              5.000000         4.000000           5.000000
# 22              3.500000         1.500000           3.000000
# 23              4.111111         3.888889           3.777778
# 24              2.625000         3.750000           4.125000
# 25              4.000000         3.500000           5.000000
# 26              4.000000         5.000000           4.000000
# 27              3.000000         4.000000           4.000000
# 28              2.500000         4.000000           4.500000
# 29              1.000000         4.500000           2.500000
# ..                   ...              ...                ...
# 108             2.000000         2.000000           5.000000
# 109             2.500000         3.000000           3.250000
# 110             2.000000         3.666667           4.666667
# 111             3.500000         3.000000           3.000000
# 112             5.000000         3.000000           5.000000
# 113             4.000000         3.000000           5.000000
# 114             1.000000         4.000000           5.000000
# 115             3.333333         3.333333           2.666667
# 116             4.000000         4.000000           2.000000
# 117             3.307692         3.615385           3.923077
# 118             3.714286         2.714286           3.428571
# 119             3.200000         3.600000           3.800000
# 120             3.592593         2.555556           3.481481
# 121             2.437500         3.125000           3.312500
# 122             2.500000         3.500000           3.800000
# 123             3.200000         2.400000           3.400000
# 124             2.857143         3.857143           4.214286
# 125             3.600000         2.400000           3.300000
# 126             4.333333         2.666667           2.333333
# 127             3.000000         4.000000           5.000000
# 128             5.000000         5.000000           5.000000
# 129             4.000000         4.000000           4.000000
# 130             3.000000         4.000000           3.000000
# 131             3.000000         4.000000           4.000000
# 132             3.166667         3.166667           3.166667
# 133             2.500000         4.000000           5.000000
# 134             1.000000         1.000000           4.000000
# 135             3.500000         3.000000           4.500000
# 136             2.857143         3.142857           3.142857
# 137             2.500000         2.500000           3.000000
#
# [138 rows x 10 columns]

# %%
#now we're going to create a column in that df that lists whichever factor was the most impactful in moving for each row:
psMove['factor1'] = psMove[['res_factors_hhchange',
 'res_factors_afford',
 'res_factors_school',
 'res_factors_walk',
 'res_factors_space',
 'res_factors_closefam',
 'res_factors_transit',
 'res_factors_hwy',
 'res_factors_30min']].idxmax(axis=1)

psMove.factor1 #let's verify that worked
# Out:
# 0        res_factors_afford
# 1        res_factors_afford
# 2        res_factors_afford
# 3          res_factors_walk
# 4      res_factors_hhchange
# 5        res_factors_school
# 6        res_factors_afford
# 7      res_factors_closefam
# 8        res_factors_afford
# 9        res_factors_afford
# 10     res_factors_hhchange
# 11       res_factors_afford
# 12       res_factors_afford
# 13          res_factors_hwy
# 14         res_factors_walk
# 15        res_factors_space
# 16       res_factors_afford
# 17        res_factors_30min
# 18       res_factors_afford
# 19         res_factors_walk
# 20       res_factors_afford
# 21       res_factors_afford
# 22        res_factors_space
# 23       res_factors_afford
# 24       res_factors_afford
# 25       res_factors_afford
# 26       res_factors_afford
# 27       res_factors_afford
# 28        res_factors_30min
# 29         res_factors_walk
#                ...
# 108    res_factors_hhchange
# 109      res_factors_afford
# 110      res_factors_afford
# 111      res_factors_school
# 112     res_factors_transit
# 113      res_factors_afford
# 114      res_factors_afford
# 115      res_factors_afford
# 116      res_factors_afford
# 117        res_factors_walk
# 118        res_factors_walk
# 119      res_factors_afford
# 120      res_factors_afford
# 121      res_factors_afford
# 122        res_factors_walk
# 123      res_factors_afford
# 124      res_factors_afford
# 125      res_factors_afford
# 126      res_factors_afford
# 127      res_factors_school
# 128      res_factors_afford
# 129      res_factors_afford
# 130    res_factors_hhchange
# 131      res_factors_afford
# 132      res_factors_afford
# 133      res_factors_afford
# 134      res_factors_afford
# 135       res_factors_30min
# 136      res_factors_afford
# 137       res_factors_space
# Name: factor1, Length: 138, dtype: object

# %%
psMove.factor1.dtype #checking the dtype
# Out:
# dtype('O')

# %%
#we want that to be a category, so:
from pandas.api.types import CategoricalDtype
psMove.factor1=psMove.factor1.astype(CategoricalDtype(categories=resfacNames, 
                                         ordered=True))

# %%
psMove.factor1.dtype
# Out:
# CategoricalDtype(categories=['res_factors_hhchange', 'res_factors_afford',
#                   'res_factors_school', 'res_factors_walk',
#                   'res_factors_space', 'res_factors_closefam',
#                   'res_factors_transit', 'res_factors_hwy',
#                   'res_factors_30min'],
#                  ordered=True)

# %% [markdown]
# # Step 6: Let's create a map to see which factors in moving make the biggest difference for each zipcode

# %%
#step one: getting map info
compressedMap=os.path.join(folderData,'WaZipsMap.zip')

import geopandas as gpd

waZipMap = gpd.GeoDataFrame.from_file(compressedMap)

waZipMap.head()
# Out:
#   ZCTA5CE10      AFFGEOID10 GEOID10    ALAND10  AWATER10  \
# 0     21914  8600000US21914   21914    1924479    477175
# 1     01001  8600000US01001   01001   29731610   2118827
# 2     34736  8600000US34736   34736  322808220  78588518
# 3     46151  8600000US46151   46151  530632048   9804480
# 3294   POLYGON ((-122.415048884331 47.57851284527401,...
# ...                                                  ...
# 22633  POLYGON ((-122.58053 47.744556, -122.577083 47...
# 22634  POLYGON ((-122.79681 47.348268, -122.795303 47...
# 25246  POLYGON ((-122.38744 47.66322, -122.380401 47....
# 25576  POLYGON ((-122.229982 47.265887, -122.228835 4...
# 25683  POLYGON ((-122.328546 47.897917, -122.32747883...
# 26737  POLYGON ((-122.306877 47.289673, -122.29593 47...
# 26749  POLYGON ((-122.684555 47.610816, -122.679455 4...
# 26833  POLYGON ((-122.557013 47.118508, -122.542727 4...
# 26847  (POLYGON ((-122.044964 47.315475, -122.042041 ...
# 26848  POLYGON ((-122.603391 47.667928, -122.60175 47...
# 26855  POLYGON ((-122.187795 47.851767, -122.18691 47...
# 26979  POLYGON ((-122.184486 48.09799599999999, -122....
# 27033  POLYGON ((-122.741737 47.155045, -122.737579 4...
# 27442  POLYGON ((-122.333273 47.788137, -122.331843 4...
# 27645  POLYGON ((-122.781849583041 47.659422915062, -...
# 27752  POLYGON ((-122.263328 47.262355, -122.262902 4...
# 31609  POLYGON ((-122.129528 47.567302, -122.127071 4...
# 31618  POLYGON ((-122.219133 47.52372099999999, -122....
# 31683  POLYGON ((-122.327855 47.618495, -122.324259 4...
# 31684  POLYGON ((-122.320448 47.442152, -122.321039 4...
# 31796  POLYGON ((-122.405473654783 48.2519780903618, ...
# 32001  POLYGON ((-122.335293 47.503121, -122.333654 4...
# 32090  POLYGON ((-122.224897 47.144943, -122.224965 4...
# 32102  POLYGON ((-122.617022 47.938987, -122.611956 4...
# 32128  POLYGON ((-122.655551 47.555162, -122.655152 4...
# 32331  POLYGON ((-122.708419 47.07843399999999, -122....
# 32343  POLYGON ((-122.231835 47.69012, -122.216735 47...
# 32597  POLYGON ((-122.154938 47.584634, -122.153431 4...
# 32955  POLYGON ((-122.658036 47.127166, -122.650634 4...
# 33017  POLYGON ((-122.329289 47.701432, -122.328527 4...
#
# [189 rows x 6 columns]

# %%
psMoveMap=waZipMap.merge(psMove, left_on='ZCTA5CE10', right_on='h_zip') ## merging data into shapefile

# %%
# %matplotlib inline
base = waZipMap.plot(color='#ededed',figsize=(20,13))

#psrchhWAmap.plot(ax=base, color='pink')
psMoveMap.plot(ax=base,column='factor1',cmap='tab20',categorical=True,legend=True)

# %% [markdown]
# # Step 7: Since we can see that affordability is the biggest factor in most places, let's explore that a bit more

# %%
import seaborn as sns
import matplotlib.pyplot as plt # needed for more customization
from scipy.stats import norm
#statistics:
mnVar=psrchh['res_factors_afford'].mean()
mdVar=psrchh['res_factors_afford'].median()

sns.distplot(psrchh['res_factors_afford'].dropna(),kde=False,fit=norm)
plt.title('Importance of Affordability in Moves')
plt.axvline(mnVar, color='b', linestyle='dashed', linewidth=2,label='mean')
plt.axvline(mdVar, color='r', linestyle='dashed', linewidth=2,label='median')
plt.legend() #I should update this to include more info
